# %% [markdown]
# # 微调

# %%
# %matplotlib inline
import os
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

# %% [markdown]
# 热狗数据集来源于网络

# %%
d2l.DATA_HUB['hotdog'] = (d2l.DATA_URL + 'hotdog.zip',
                         'fba480ffa8aa7e0febbb511d181409f899b9baa5')

data_dir = d2l.download_extract('hotdog')
# Out:
# Downloading ..\data\hotdog.zip from http://d2l-data.s3-accelerate.amazonaws.com/hotdog.zip...

# %%
train_imgs = torchvision.datasets.ImageFolder(os.path.join(data_dir, 'train'))
test_imgs = torchvision.datasets.ImageFolder(os.path.join(data_dir, 'test'))

# %% [markdown]
# 图像的大小和纵横比各有不同

# %%
hotdogs = [train_imgs[i][0] for i in range(8)]
not_hotdogs = [train_imgs[-i - 1][0] for i in range(8)]
d2l.show_images(hotdogs + not_hotdogs, 2, 8, scale=1.4);

# %% [markdown]
# 数据增广

# %%
normalize = torchvision.transforms.Normalize(
    [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
# 因为在IMAGENET上训练的模型，所以需要使用IMAGENET的均值和方差进行归一化

train_augs = torchvision.transforms.Compose([
    torchvision.transforms.RandomResizedCrop(224), # 随机裁剪
    torchvision.transforms.RandomHorizontalFlip(), # 随机水平翻转
    torchvision.transforms.ToTensor(),             # 转换为张量
    normalize])

test_augs = torchvision.transforms.Compose([
    torchvision.transforms.Resize([256, 256]),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    normalize])

# %% [markdown]
# 定义和初始化模型

# %%
pretrained_net = torchvision.models.resnet18(pretrained=True)
# Out:
# d:\anoconda\anoconda\envs\d2l-zh\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\anoconda\anoconda\envs\d2l-zh\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\华为/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100.0%

# %%
pretrained_net.fc
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %%
finetune_net = torchvision.models.resnet18(pretrained=True)
finetune_net.fc = nn.Linear(finetune_net.fc.in_features, 2) # 重新定义最后一层的输出，因为是二分类，所以输出为2
nn.init.xavier_uniform_(finetune_net.fc.weight); # 仅初始化最后一层

# %% [markdown]
# 微调模型

# %%
def train_fine_tuning(  net, learning_rate, batch_size=128, num_epochs=5,
                        param_group=True):
    train_iter = torch.utils.data.DataLoader(torchvision.datasets.ImageFolder(
        os.path.join(data_dir, 'train'), transform=train_augs),
        batch_size=batch_size, shuffle=True)
    test_iter = torch.utils.data.DataLoader(torchvision.datasets.ImageFolder(
        os.path.join(data_dir, 'test'), transform=test_augs),
        batch_size=batch_size)
    devices = d2l.try_all_gpus()
    loss = nn.CrossEntropyLoss(reduction="none")
    if param_group: 
        # 如果使用了param_group，那么就需要将最后一层的参数单独拿出来
        params_1x = [param for name, param in net.named_parameters()
                if name not in ["fc.weight", "fc.bias"]]
        trainer = torch.optim.SGD([ {'params': params_1x},
                                    {'params': net.fc.parameters(),
                                    'lr': learning_rate * 10}],
                                    # 将最后一层的学习率设置为前面的10倍
                                lr=learning_rate, weight_decay=0.001)
    else:
        trainer = torch.optim.SGD(  net.parameters(), lr=learning_rate,
                                    weight_decay=0.001)
    d2l.train_ch13(net, train_iter, test_iter, loss, trainer, num_epochs,
                    devices)

# %% [markdown]
# 使用较小的学习率

# %%
train_fine_tuning(finetune_net, 5e-5)

# 学习率很小了

# 会发现一开始就很好
# Out:
# loss 0.177, train acc 0.932, test acc 0.943
# 968.4 examples/sec on [device(type='cuda', index=0), device(type='cuda', index=1)]

# %% [markdown]
# 为了进行比较，
# 所有模型参数初始化为随机值

# %%
scratch_net = torchvision.models.resnet18()
scratch_net.fc = nn.Linear(scratch_net.fc.in_features, 2)
train_fine_tuning(scratch_net, 5e-4, param_group=False)

# %%
for param in finetune_net.parameters():
    param.requires_grad = False

weight = pretrained_net.fc.weight
hotdog_w = torch.split(weight.data, 1, dim=0)[934]
hotdog_w.shape
# Out:
# torch.Size([1, 512])
